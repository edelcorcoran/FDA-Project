# %% [markdown]
# # Edel Corcoran GMIT ID #:G00010824
# # Fundamentals of Data Analytics
# # Project: Tips Dataset
# # Lecturer: Ian McLoughlin

# %% [markdown]
# **Project Layout**
#
# **1. Introduction**
#
# - About the Project
#
# - What is the Tips Dataset?
#
# - Contents
#
# - Tipping Culture
#
# - Why collect the dataset / Purpose?
#
# **2. Layout/Summary of Dataset**
#
# - Import Dataset
#
# - Summary/Layout of Dataset
#
# **3.Descriptive Stats / Analysis**
#
# - Areas of interest to investigate
# - What is a Summary Descriptive Statistics Table?
# - Descriptive Statistics for Entire Dataset with analysis
# - Add Columns
# - Investigate Bill and Tip as %
# - Understanding the Plots.
#
# **Numerical Data**
#
# - Histograms/Frequency Distributions/Plots/Tables for numerical variables with analysis of data and patterns
# - Questions & Analysis throughout
#
# **Categorical Data**
#
# - Pie Charts/Plots/Tables for categorical variables with analysis of data and patterns
# - Questions & Analysis throughout
#
# ** Multiple Variables**
#
# Plots: Boxplot/Histograms/Pie charts
#
# **Multiple Variables**
#
# - Tables/Plots/Pairplots etc & Analysis
#
#
# **4.Regression - Is there a relationship between total bill and tip?**
#
# - Is there a relationship between total bill and tip?
# - Plots/code
# - Analysis/findings
#
# **5. Conclusion / Summary**
#
# - Main findings of investigation
# - Real life relevence of findings
#
# **6.References / Bibliography**

# %% [markdown]
# # 1.Introduction

# %% [markdown]
# **About the project**
#
# This project looks at a dataset and has three core aims and they are firstly to describe it’s content and purpose as well as use a jupyter notebook conatining python code and imported libraries to help create statistics and plots to help visualise the datasets, secondly the project will analyse the data looking at investigations in an effort to identify patterns (eg. Distribution) and relationships between various variables within the dataset,  thirdly the topic of regression between two specific variables will be explored.
#
# Throughout the project relevant questions in regards to the real-life importance of the dataset will be looked at with investigations to attempt to answers these questions and analyse all findings.
#
# **What is the Tips Dataset?**
#
# Throughout this project the ‘Tips’ dataset will be studied.  The dataset contains both categorical data (eg. sex) and numerical data (eg.tip amount). In 1990 a food waiter/waitress recorded data on all customers they served over a period of two and a half months. In short the dataset contains 244 observations on 7 variables outlined below;
#
# **Contents**
#
# -	total_bill = cost of the meal, including tax, in US dollars
# -	tip = Tip/gratuity in US dollars
# -	sex = the sex of person paying for the meal
# -	smoker = is there a smoker in party
# -	day = Thur / Fri / Sat /Sun
# -	time = Day (lunch) / Night (dinner)
# -	size = size of the party
#
# **Tipping Culture**
#
#  “A gratuity (also called a tip) is a sum of money customarily given by a client or customer to certain service sector workers for the service they have performed, in addition to the basic price of the service…..Tips and their amount are a matter of social custom and etiquette, and the custom varies between countries and between settings” [1.Wikipedia]. In America there is a strong tipping culture which is evident to anyone who has travelled or spent time in the USA. “The tipped wage is base wage paid to an employee that receives a substantial portion of their compensation from tips”[2.Wiki] and the minimum tipped wage varies from state to state in the USA for instance it’s only USD2.13 in Alabama but USD12.50 in parts of Oregon.
# “TIPPING is a hallmark of dining out in America. But it is controversial. The gratuity system ensures that it is the diners who determine a server’s pay. Those who support the practice say it rewards dutiful service; others call it capricious and argue that a professional server’s wages should not be discretionary”[3. Economist].
#
# (USD = United States Dollars)
#
# **Why Collect the data?**
#
# Some of the background information on the tipping culture outlined above may trigger some ideas for you as to why the tips dataset was collected and the purpose it serves. It’s clear that tips can have a crucial effect on the take home pay of any person working in the food industry in a country like America. “Food servers’ tips in restaurants may be influenced by many factors, including the nature of the restaurant, size of the party, and table locations in the restaurant. Restaurant managers need to know which factors matter when they assign tables to food servers. For the sake of staff morale, they usually want to avoid either the substance or the appearance of unfair treatment of the servers, for whom tips (at least in restaurants in the United States) are a major component of pay”[4 .Kaggle]. As well as the issues of morale and work schedules for employers the dataset may help in answering interesteing questions like;
#
# Interesting Questions
#
# -	Is regression evident in the dataset?
# -	Are men better tippers than women?
# -	Are there distribution patterns evident?
# -   Is there a better day/time to work as a waiter?

# %% [markdown]
# ## 2. Layout / Summary of Dataset

# %% [markdown]
# **Import Dataset/Libraries**

# %% [markdown]
# The libraries utilised throughout this notebook are imported below to assist with data analysis and visualising the tips dataset.

# %%
#import packages necessary
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# The tips dataset in csv format was acquired from the Kaggle.com website. It's loaded below as a pandas dataframe:

# %%
# Load the Tips Dataset [5.Kaggle.com]
# "Use read_csv method to read the raw data in the CSV file into a data frame, df . The data frame is a two-dimensional array-like data structure for statistical and machine learning models."[6]
df = pd.read_csv("tips.csv")

# %% [markdown]
# The code below displays the entire dataset for viewing. All 7 columns and 244 rows are visible plus an index on the far left.

# %%
#Display dataframe
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %% [markdown]
# **Layout & Summary of Tips Dataset**

# %% [markdown]
# The code below helps describe the type of data for each variable (eg. Numerical data as floats or integers / Categorical as object etc). This helps summarise the contents in that it outlines clearly the number of entries in each column ie. 244 in all columns. Also there's no missing entries/values in any column.

# %%
#Display further details of the data type in the dataset. Illustrates there's 244 entries. "Float64" and "int64" indicates numerical data columns. "Object" indicates categorical data columns. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %% [markdown]
# The next few pieces of code help illustrate the dataset layout. ie. index, columns, values.

# %%
#Display the index. Illustrates the dataframe index(row labels)
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %% [markdown]
# The code below clearly describes the columns within the dataset.

# %%
#Display the columns
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# The code below shows an array for each column in dataset.

# %%
#Display the values
df.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %% [markdown]
# A quick look at the start and end of the dataset:

# %%
#Quick look at first 5 rows of Dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Quick look at the last 5 rows of the dataset
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # 3.Descriptive Statistics / Analysis

# %% [markdown]
# **What the Summary Statistics Table is?**
#
# A table is displayed below which gives a column for each numberical variables ie.tip, total_bill and size. The following columns of the dataset are non-numerical and are therefore excluded: sex, smoker, day and time.
#
# - **count** is the number of valid values in the column ie.244 per column
# - **mean** is the average for all values in the column
# - **std** is the standard deviation per column. How a set of values spread out from the mean. Low SD indicates values are close to the mean whilst high SD shows high diversion from the mean
# - **min** is the minimum value per column
# - **25%** 25% of values are below this number
# - **50%** is the median value ie.half of the values are above this number and half are below it
# - **75%** 75% is median of top half of values
# - **max** maximum value
#
# Knowing the quartiles (25% / 75%) assists in seeing how spread out the values are and what the distributions is like.

# %% [markdown]
# A table of descriptive statistics for the numerical data columns in the  dataset is visible below:

# %%
#Display summary statistics
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# **Interesting facts from table above:**
#
#     - Average bill was 19.78 US Dollars
#     - Average tip was 2.99 US Dollars
#     - Average party was 2.56 people
#     - Standard Deviation for tip is low at 1.38 which indicates that the tip values in the dataset don't spread out and are rather close to the mean of 2.99
#     - Standard Deviation for (party) size is low also at 0.95 so again size values don't spread out far from the mean.
#     - Reality: Waiter/Employer can expect average tip of almost $3

# %% [markdown]
# **Add New Columns to Dataset - 'BillandTip & TipPercent'**
#
# These extra columns will help look at tips as a percentage of the bill and clarify the actual complete bill including the tip paid.

# %%
# Add a new column which sums the 'total_bill and tip columns' (ie.total paid)
BillandTip = df.total_bill + df.tip # Outline 2 columns to sum
df['BillandTip'] = BillandTip # Set name of new column

# %%
TipPercent = df.tip/df.total_bill * 100
df['TipPercent'] = TipPercent

# %% [markdown]
# **Investigate Tip/Bill by Percentage**

# %%
df.describe() # now look at Summary Statistics with new Columns
# Out:
#        total_bill         tip        size  BillandTip  TipPercent
# count  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672   22.784221   16.080258
# std      8.902412    1.383638    0.951100    9.890116    6.107220
# min      3.070000    1.000000    1.000000    4.070000    3.563814
# 25%     13.347500    2.000000    2.000000   15.475000   12.912736
# 50%     17.795000    2.900000    2.000000   20.600000   15.476977
# 75%     24.127500    3.562500    3.000000   27.722500   19.147549
# max     50.810000   10.000000    6.000000   60.810000   71.034483

# %% [markdown]
# **Fact to note from Table above:**
#
#     - Average bill including tip (total paid) was $22.78
#     - Average tip as a % of total_bill was 16.08%
#     - Standard deviation of TipPercent is 6.1%
#     - Real Life Relevance: A brief look at the 'TipPercent' column from lowest to highest % indicates that on a good day the waiter could get a 71% tip but on a bad day as low as 3.56% that's a big difference so outliers likely.
#     - Reality: So for any waiter/waitress working in this industry the notable detail here is that you can expect an average tip of 16% of total_bill.
#     - Reality: Knowing average tip % might also assist employers is setting a reasonable hourly rate of day to ensure staff can exist on their overall income.

# %%
#Sort data based on tip from low to high
df.sort_values(by='TipPercent', ascending=True)
# Out:
#      total_bill   tip     sex smoker   day    time  size  BillandTip  \
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2       34.00
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3       46.80
# 57        26.41  1.50  Female     No   Sat  Dinner     2       27.91
# 0         16.99  1.01  Female     No   Sun  Dinner     2       18.00
# 187       30.46  2.00    Male    Yes   Sun  Dinner     5       32.46
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3       32.06
# 48        28.55  2.05    Male     No   Sun  Dinner     3       30.60
# 146       18.64  1.36  Female     No  Thur   Lunch     3       20.00
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       29.18
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2       43.55
# 182       45.35  3.50    Male    Yes   Sun  Dinner     3       48.85
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4       41.73
# 130       19.08  1.50    Male     No  Thur   Lunch     2       20.58
# ...

# %% [markdown]
# **Understanding The Plots**

# %% [markdown]
# **What is a boxplot?**
#
# "A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”). It can tell you about your outliers and what their values are. It can also tell you if your data is symmetrical, how tightly your data is grouped, and if and how your data is skewed." [9]
#
# This image points out the various parts of a boxplot for you understanding:
#
#
# <img src="Boxplot.png">

# %% [markdown]
# **Scatterplot**
#
# The dots in the plot represent observations from the tips dataset. A scatterplot is used to display the relationship between the two variables (tip & sex). A scatterplot consists of the varibale 'sex' on the x-axis and 'tip' on the y-axis.

# %% [markdown]
# **Violin Plot**
#
# This plot combines box plots and density plots to illustrate the frequency distribution along with box plot.

# %% [markdown]
# **Histograms**
#
# These are used to illustrate the distribution frequency of continuous data. Along the horizontal axis there are ranges and along the vertical axis are the number of occurrences. Bins are used similarly to Bar charts.

# %% [markdown]
# **Numerical Data**

# %% [markdown]
# Questions:
#
# - Type of distibution for numerical variables ie. Normal (bell-shaped), Skew left/right etc ?
# - What's the average tip/bill/group amount?
# - What's the average tip as a percentage of bill?
# - Any patterns in tipping?

# %% [markdown]
# - _TIP_

# %%
# #Pull data from dataset
tips = sns.load_dataset("tips")

# %%
#Alter size of plot/figure
fig=plt.figure(figsize=(12, 8))
#Histogram to illustrate frequency distribution of tip with gaussian kernel density estimate ("kde=True")
sns.distplot(tips['tip'], kde=True, bins=10).set_title("Frequency Distribution of Tip");
plt.show()
# Out:
# C:\Users\edel_\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# It's evident from the plot above that most tips fall between 2 and 4 USDollars(ie. the two peaks/bins in histogram) with a distribution which skews right, the boxplot also illustrates this pattern. A distribution which skews right indicates more values are above the peaks rather than below them.

# %%
# Boxplot to illustrate data distribution for Tip amount
# create grid style
sns.set(style="darkgrid")
#Alter plot size
fig = plt.figure(figsize=(12, 4))
# pull data from dataset
tips = sns.load_dataset("tips")
#Display boxplot with label on x-axis and add title
ax = sns.boxplot(x=df["tip"]).set_title("Distribution of Tip")

# %% [markdown]
# In the boxplot above you can see there's visible outliers to the right but the interquartile range (blue box) is located between 2 dollars and about 3.75 dollars so 50% of observations fall inside those tip amounts.

# %%
#Scatterplot to see if tips are still mostly between 2-4 when broken into sex
sns.catplot(x="sex", y="tip", palette="Set1", data=tips)
#Display plot
plt.show()

# %% [markdown]
# Question: Do men/women tip differently?
#
# - The scatterplot for tip amounts above exhibits the distribution of values based on sex. The distributions look very similar with more outliers evident in the male section. So women seems to be more consistent tippers than men.
# - The table below breaks tip data into male/female statistics which show mean tip for women is 2.83 dollars and 3.08 dollars for men and indeed the standard deviation for women is smaller at 1.15.

# %%
df.groupby(by='sex')['tip'].describe() # Desriptive Statistics table by tip
# Out:
#         count      mean       std  min  25%   50%   75%   max
# sex
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0

# %% [markdown]
# - _TOTAL BILL_

# %%
#Alter size of plot/figure
fig=plt.figure(figsize=(12, 8))
#Histogram to illustrate frequency distribution of total_bill with gaussian kernel density estimate ("kde=True")
sns.distplot(tips['total_bill'], kde=True, bins=10).set_title("Frequency Distribution of 'total_bill' variable");
plt.show()

# %% [markdown]
# The majority of 'total_bills' are visible between 9-25 dollars (ie.peaks in plot). The distribution skews right which means there's more values above 25 than below 9 which is evident in the boxplot below:

# %%
# Boxplot to illustrate data distribution for total_bill
# create style
sns.set(style="darkgrid")
#Alter plot size
fig = plt.figure(figsize=(12, 4))
# pull data from dataset
tips = sns.load_dataset("tips")
#Display boxplot with label on x-axis and add title
ax = sns.boxplot(x=tips["total_bill"]).set_title("Distribution of total_bill")

# %% [markdown]
# - _SIZE_

# %%
#Alter size of plot/figure
fig=plt.figure(figsize=(12, 8))
#Histogram to illustrate frequency distribution of party 'size' with gaussian kernel density estimate ("kde=True")
sns.distplot(tips['size'], kde=True, bins=10).set_title("Frequency Distribution of 'size' variable");
plt.show()

# %% [markdown]
# The highest number in regards to party size is obviously closest to 2 people (2-2.5 is the peak bin). The distribution is skewed to the right so more values for 'size' are above 2 rather than below 2.
#
# The boxplot below shows that interquartile range lies between 2-3 for party size. So 50% of groups are between 2 and 3. Outliers are visible to the right clarifying the distribution skews right.

# %%
# Boxplot to illustrate data distribution for party size
# create grid style
sns.set(style="darkgrid")
#Alter plot size
fig = plt.figure(figsize=(12, 4))
# pull data from dataset
tips = sns.load_dataset("tips")
#Display boxplot with label on x-axis and add title
ax = sns.boxplot(x=df["size"]).set_title("Distribution of Size")

# %% [markdown]
# In the boxplot above there outliers visible to the right which indicates few parties of size 5-6.

# %% [markdown]
# - _BILL including TIP_

# %%
#Alter size of plot/figure
fig=plt.figure(figsize=(12, 8))
#Histogram to illustrate frequency distribution of the entire bill with tip included with gaussian kernel density estimate ("kde=True")
sns.distplot(df['BillandTip'], kde=True, bins=10).set_title("Frequency Distribution of the BillandTip");
plt.show()

# %% [markdown]
# Again in the frequency distruibution above the plot skews to the right with clear peaks between 10 and around 26 dollars for complete bill (total_bill + tip variables). So more values are above 26 as opposed to below it, this is also confirmed by the boxplot (BillandTip) will shows the distributions skewing right with clear outliers present.

# %%
# Boxplot to illustrate data distribution for Bill including Tip
# create grid style
sns.set(style="darkgrid")
#Alter plot size
fig = plt.figure(figsize=(12, 4))
# pull data from dataset
tips = sns.load_dataset("tips")
#Display boxplot with label on x-axis and add title
ax = sns.boxplot(x=df["BillandTip"]).set_title("Distribution of BillandTip")

# %% [markdown]
# **In summary**, the frequency distributions for the numerical data variables looked at above all skew right with visible peaks more so to the left of each plot. When high peaks are visible in a frequency distribution over a small number of bins (sections) with much smaller peaks radiating outwards from them (skewing to the right in the numerical data above) then we can conclude that most values fall within a fairly small range (eg. most tips between 2-4).
#
# The boxplots all show compact interquartile ranges for numerical variables so values aren't very widespread with the exception of some outliers.
#
# Notable facts so far:
# - Average bill was 19.78 US Dollars
# - Average tip was 2.99 US Dollars
# - Average party was 2.56 people
# - Average tip was 16% of total_bill which doesn't change much for men/women.
# - Pattern: Women tip less by % but are more consistent tippers than men but generous tip is more likely to come from a man.
# - Most total bill fall between 10-26 dollars
# - Most groups are between 2-3 people with few groups of 5 or 6.
# - Distributions all skew right.
# - Reality: Can expect an average tip of 16% of total_bill.
# - Reality: Knowing average tip % might also assist employers is setting a reasonable hourly rate of day to ensure staff can exist on their overall income.

# %% [markdown]
# **Categorical Data**

# %% [markdown]
# The piechart below give an insight into the categorical data within the tips dataset. They break categories into percentages.
#
# Notable facts:
# - Bill payers are 64.3% male vs 35.7% female. So there's almost twice as many men to women is this dataset
# - The busiest day is Saturday (35.7%) followed by Sunday (31.1%) next is Thursday (25.4%) and finally Friday (7.8%).
# - 61.9% are non-smokers vs 38.1% smokers
# - dinner was the busiest time of day with 72.1% vs lunchtime with 27.9%
# - Group size: solo diner (1.6%), 2 diners (63.9%), three diners (15.6%), 4 diners (15.2%), 5 (2%) & 6 (1.6%)
#
# These charts help visualise the breakdown of the categorical data.

# %%
# pie charts to represent categorical data (sex/day/smoker/time) by percentage

# for the category 'sex' what % is male/female. Illustrate this in a pie chart
sex = df.groupby('sex').size()
plt.pie(sex, labels=sex.index, radius=1.5, autopct='%1.1f%%')
plt.show()

# for the category 'day' what % is thur/fri/sat/sun. Illustrate this in a pie chart
day = df.groupby('day').size()
plt.pie(day, labels=day.index, radius=1.5, autopct='%1.1f%%')
plt.show()

# for the category 'smoker' what % is smoker/non-smoker. Illustrate this in a pie chart
smoker = df.groupby('smoker').size()
plt.pie(smoker, labels=smoker.index, radius=1.5, autopct='%1.1f%%')
plt.show()

# for the category 'time' what % is lunch time/dinner time. Illustrate this in a pie chart
time = df.groupby('time').size()
plt.pie(time, labels=time.index, radius=1.5, autopct='%1.1f%%')
plt.show()

# for the category 'size' what % is size=1,2,3,,etc. Illustrate this in a pie chart
time = df.groupby('size').size()
plt.pie(time, labels=time.index, radius=1.5, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Does Party Size have an influence on tips?**

# %% [markdown]
# The smallest party size was 1 and the largest was 6 but overall how did the 244 groups breakdown by size??
#
# Illustrated below is a breakdown of party size from 1 to 6 (left) with number of occurences (right) (eg. there was 156 groups of 2 people).

# %%
# Take 'size' column and illustrate the number occurences in dataset . ie the were 4 parties of just 1 customer, 156 parties of 2 customers etc..
df.groupby(by='size').size()
# Out:
# size
# 1      4
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# dtype: int64

# %% [markdown]
# Earlier it was noted that few groups were large (5/6) the table above confirms that pattern.
#
# In the table below you can see the mean tip for each party size, it's lowest for solo diners (1.43) and highest for groups of 6 (5.22) which you would expect. By percentage of bill the tip mostly ranges from 14 to 16.5% with the exception of solo diners who leave a mean tip of 21.7%.
#
# As group size increase so does the total_bill & tip so there a positive increasing pattern.

# %%
# Look at average values for numerical data (totalbill/tip/BillandTip/TipPercent) based on group size.
df.groupby(by='size').mean()
# Out:
#       total_bill       tip  BillandTip  TipPercent
# size
# 1       7.242500  1.437500    8.680000   21.729202
# 2      16.448013  2.582308   19.030321   16.571919
# 3      23.277632  3.393158   26.670789   15.215685
# 4      28.613514  4.135405   32.748919   14.594901
# 5      30.068000  4.028000   34.096000   14.149549
# 6      34.830000  5.225000   40.055000   15.622920

# %% [markdown]
# Note: The were very few groups of 1/5/6 people so data for those group sizes aren't going to be very reliable.
#
# The standout piece of information in the table above is that the best tip by percentage is from groups of  2 people (given low number of solo diners the 21.7% can't be taken as reliable). **The groups of 2 tip better by percentage than larger groups**. It would appear gorups of 2 are the best tippers.
#
# Reality: Is a waiter better of by serving groups of two rather than large parties? If there was data on the time taken to serve each table perhaps this would be interesting to investigate further.

# %% [markdown]
# - **Male vs Female**
#
# Interesting questions:
#
# - Who tips better men or women?
# - Do men spend more on average?
# - What is the average tip as a % of bill for men/women?
# - Do any obvious patterns emerge that might be of interest to a waiter/waitress?

# %% [markdown]
# The data contained within the dataset is broken down in the code below to help clearly understand any differences between males and females. Some facts and figures are outlined below:

# %% [markdown]
# The table below tells us:
#
# **Count**
# - More men than woman in count figures 157 vs 87
#
#
# **Means/Averages**
# - Male: mean total_bill = 20.74 / mean tip = 3.08 dollars or 15.76% / mean size = 2.63
# - Female: mean total_bill = 18.05 / mean tip = 2.83 dollars or 16.64% / mean size = 2.45
#
# **Note**
#
# - Pattern: **Males have greater average bills, tip amounts & party size**
# - However **women leave a smaller tip amount but that tip is a greater percentage of their bill at 16.64%** versus 15.76% for men.

# %%
df.groupby(by='sex')['total_bill'].describe() # Desriptive Statistics table by sex
# Out:
#         count       mean       std   min    25%    50%    75%    max
# sex
# Female   87.0  18.056897  8.009209  3.07  12.75  16.40  21.52  44.30
# Male    157.0  20.744076  9.246469  7.25  14.00  18.35  24.71  50.81

# %%
df.groupby(by='sex')['tip'].describe() # Desriptive Statistics table by tip
# Out:
#         count      mean       std  min  25%   50%   75%   max
# sex
# Female   87.0  2.833448  1.159495  1.0  2.0  2.75  3.50   6.5
# Male    157.0  3.089618  1.489102  1.0  2.0  3.00  3.76  10.0

# %%
df.groupby(by='sex')['TipPercent'].describe() # Desriptive Statistics table by TipPercent
# Out:
#         count       mean       std       min        25%        50%        75%  \
# sex
# Female   87.0  16.649074  5.363173  5.643341  14.041645  15.558149  19.426621
# Male    157.0  15.765055  6.477787  3.563814  12.138869  15.349194  18.623962
#
#               max
# sex
# Female  41.666667
# Male    71.034483

# %%
df.groupby(by='sex')['size'].describe() # Desriptive Statistics table by party size
# Out:
#         count      mean       std  min  25%  50%  75%  max
# sex
# Female   87.0  2.459770  0.937644  1.0  2.0  2.0  3.0  6.0
# Male    157.0  2.630573  0.955997  1.0  2.0  2.0  3.0  6.0

# %% [markdown]
# The distribution of 'tip' is illustrated in the boxplot below which shows the distribution is more so skewed right for males whilst it's more of a normal distribution for women (ie. more consistent). The clearly more outlier in the male section. A waiter/waitress maybe more likely to get a generous tip from a man rather than a woman based on these distributions.

# %%
#Select style of grid
sns.set(style="darkgrid")
#Alter plot size
fig = plt.figure(figsize=(8, 8))
# Display boxplot with sex on x-axis and tip on y-axis
ax = sns.boxplot(x="sex", y="tip", palette="Set1", data=tips).set_title("Distribution of Tip for Males/Females")

# %% [markdown]
# **2.DAY**
#
# - Are certains busier that others?
# - Are tips better at the weekend?

# %% [markdown]
# Information from the tables below show that:
#
# **Count**
# - Saturday is the busiest day with a count of 87 followed by Sunday at 76 then Thursday at 62 with Friday way behind at 19. Hence Fridays data may not be very relible given small sample.
#
# **Means/Averages**
# - Mean total bill by day is highest on Sunday at 21.41 dollars and lowest on Friday at 17.15 dollars
# - Mean tip amount is highest on Sunday at 3.25 dollars followed in second place at 2.99 dollars on Saturdays (the weekend days)
# - Mean tip by percentage is highest on Friday at 16.99% followed on Sunday at 16.68%. Given the low sample count for Friday this may not be very reliable.
# - Standard deviation is high for TipPercent on Sunday which appears to be impacted by one generous customer who left a 71% tip (outlier).

# %%
df.groupby(by='day')['total_bill'].describe() # Desriptive Statistics table by day for total_bill
# Out:
#       count       mean       std   min      25%    50%      75%    max
# day
# Fri    19.0  17.151579  8.302660  5.75  12.0950  15.38  21.7500  40.17
# Sat    87.0  20.441379  9.480419  3.07  13.9050  18.24  24.7400  50.81
# Sun    76.0  21.410000  8.832122  7.25  14.9875  19.63  25.5975  48.17
# Thur   62.0  17.682742  7.886170  7.51  12.4425  16.20  20.1550  43.11

# %%
df.groupby(by='day')['tip'].describe() # Desriptive Statistics table by day for tip
# Out:
#       count      mean       std   min     25%    50%     75%    max
# day
# Fri    19.0  2.734737  1.019577  1.00  1.9600  3.000  3.3650   4.73
# Sat    87.0  2.993103  1.631014  1.00  2.0000  2.750  3.3700  10.00
# Sun    76.0  3.255132  1.234880  1.01  2.0375  3.150  4.0000   6.50
# Thur   62.0  2.771452  1.240223  1.25  2.0000  2.305  3.3625   6.70

# %%
df.groupby(by='day')['TipPercent'].describe() # Desriptive Statistics table by day for TipPercent
# Out:
#       count       mean       std        min        25%        50%        75%  \
# day
# Fri    19.0  16.991303  4.766531  10.355540  13.373871  15.562472  19.663729
# Sat    87.0  15.315172  5.129259   3.563814  12.386329  15.183246  18.827082
# Sun    76.0  16.689729  8.473889   5.944673  11.998208  16.110332  18.788908
# Thur   62.0  16.127563  3.865182   7.296137  13.820958  15.384615  19.268675
#
#             max
# day
# Fri   26.348039
# Sat   32.573290
# Sun   71.034483
# Thur  26.631158

# %% [markdown]
# The scatterplot proves there a greater distribution of 'tip' on Saturdays which is consistent with mean figures outlined. It's clear also the reduced observations (dots) on Fridays which is clearly the least busy day in the restaurant.

# %%
#Scatterplot to see if tips are still mostly between 2-4 when broken into days
sns.catplot(x="day", y="tip", palette="Set1", data=tips)
#Display plot
plt.show()

# %% [markdown]
# Violin plot below:
#
# The only significant difference is visible on Fridays, clearly the total_bill is greater for men on Fridays. But we really need to consider the low number of observations on Fridays with it being the quietest day for business and wonder whether this information is reliable. The other days seem to mimic each other so I'd know see that there's much evidence to suggest any big difference in 'total_bill' when broken into days and gender.

# %%
# Take total_bill on the different days and look to see if there's a visible difference when data is broken into male/female categories
# Adapted code from [8]
sns.catplot(x="day", y="total_bill", hue="sex", kind="violin", palette="Set1", data=tips).set_titles("Violin Plot of total_bill & day in categories of Male/Female");
#Display plot
plt.show()

# %% [markdown]
# **3. Smoker vs Non-Smoker**
#
# - Is there any difference for tip?

# %% [markdown]
# The data provided by the tables below would suggest there's little difference in total bill and tips left based on smoker status. The mean figures are very close in the 3 tables. It was however a smoker that left that 71% tip as evident in the third table were the standard deviation is large for tip percent.

# %%
df.groupby(by='smoker')['total_bill'].describe() # Desriptive Statistics table by smoker status for total_bill
# Out:
#         count       mean       std   min     25%    50%     75%    max
# smoker
# No      151.0  19.188278  8.255582  7.25  13.325  17.59  22.755  48.33
# Yes      93.0  20.756344  9.832154  3.07  13.420  17.92  26.860  50.81

# %%
df.groupby(by='smoker')['tip'].describe() # Desriptive Statistics table by smoker status by tip amount
# Out:
#         count      mean       std  min  25%   50%    75%   max
# smoker
# No      151.0  2.991854  1.377190  1.0  2.0  2.74  3.505   9.0
# Yes      93.0  3.008710  1.401468  1.0  2.0  3.00  3.680  10.0

# %%
df.groupby(by='smoker')['TipPercent'].describe() # Desriptive Statistics table by smoker status by tip amount
# Out:
#         count       mean       std       min        25%        50%        75%  \
# smoker
# No      151.0  15.932846  3.990977  5.679667  13.690561  15.562472  18.501403
# Yes      93.0  16.319604  8.511920  3.563814  10.677083  15.384615  19.505852
#
#               max
# smoker
# No      29.198966
# Yes     71.034483

# %% [markdown]
# The scatterplot for variables 'smoker' and 'tip' doesn't show any obvious difference for tips based on smoker status which concur with mean statistics in tables.

# %%
#Scatterplot to see if tips are still mostly between 2-4 when broken into smoker status
sns.catplot(x="smoker", y="tip", palette="Set1", data=tips)
#Display plot
plt.show()

# %% [markdown]
# **4. TIME**
#
# - Are tips better in daytime or evening?
# - For staff is there a better time to work?

# %% [markdown]
# Tips based on the time of day average 3.10 dollars/15.95% at dinner versus 2.72 dollars/16.41% at lunch. So slightly better tips by % at lunch time but looking at the last table you can see the entire tip amount totals are 546.07 dollars for dinner customers during 185.51 for lunch. So dinner time is busier with lower tip %.

# %%
df.groupby(by='time')['tip'].describe() # Desriptive Statistics table by time of day status by tip amount
# Out:
#         count      mean       std   min  25%   50%     75%   max
# time
# Dinner  176.0  3.102670  1.436243  1.00  2.0  3.00  3.6875  10.0
# Lunch    68.0  2.728088  1.205345  1.25  2.0  2.25  3.2875   6.7

# %%
df.groupby(by='time')['TipPercent'].describe() # Desriptive Statistics table by time of day status by tip amount
# Out:
#         count       mean       std       min        25%        50%        75%  \
# time
# Dinner  176.0  15.951779  6.747714  3.563814  12.319151  15.540002  18.820878
# Lunch    68.0  16.412793  4.024155  7.296137  13.914666  15.408357  19.391734
#
#               max
# time
# Dinner  71.034483
# Lunch   26.631158

# %%
df.groupby('time').sum() # Sum tips by time
# Out:
#         total_bill     tip  size  BillandTip   TipPercent
# time
# Dinner     3660.30  546.07   463     4206.37  2807.513083
# Lunch      1167.47  185.51   164     1352.98  1116.069912

# %% [markdown]
# **5. Size**
#
# Does group size impact tips?

# %%
df.groupby(by='size')['total_bill'].describe() # Desriptive Statistics table by size
# Out:
#       count       mean       std    min      25%     50%      75%    max
# size
# 1       4.0   7.242500  3.010729   3.07   6.2050   7.915   8.9525  10.07
# 2     156.0  16.448013  6.043729   5.75  12.4525  15.370  19.6900  40.55
# 3      38.0  23.277632  9.407065  10.33  16.9400  20.365  27.7750  50.81
# 4      37.0  28.613514  8.608603  16.49  21.5000  25.890  34.8100  48.33
# 5       5.0  30.068000  7.340396  20.69  28.1500  29.850  30.4600  41.19
# 6       4.0  34.830000  9.382000  27.05  29.1125  32.050  37.7675  48.17

# %% [markdown]
# As you'd expect bills increase with group size as seen in mean figures above.

# %%
df.groupby(by='size')['tip'].describe() # Desriptive Statistics table by size
# Out:
#       count      mean       std   min     25%    50%     75%    max
# size
# 1       4.0  1.437500  0.506516  1.00  1.0000  1.415  1.8525   1.92
# 2     156.0  2.582308  0.985501  1.00  2.0000  2.500  3.1450   5.85
# 3      38.0  3.393158  1.557344  1.36  2.3575  3.290  3.6825  10.00
# 4      37.0  4.135405  1.640668  2.00  3.0000  3.760  5.0700   9.00
# 5       5.0  4.028000  1.440111  2.00  3.0000  5.000  5.0000   5.14
# 6       4.0  5.225000  1.053170  4.20  4.8000  5.000  5.4250   6.70

# %% [markdown]
# Tips amount generally increases as group size increase with exceptions of groups of 5 (4.02 dollars) which pay less than groups of 4.

# %%
df.groupby(by='size')['TipPercent'].describe() # Desriptive Statistics table by size
# Out:
#       count       mean       std        min        25%        50%        75%  \
# size
# 1       4.0  21.729202  8.034186  13.793103  17.077869  20.275206  24.926539
# 2     156.0  16.571919  6.684824   3.563814  13.522313  15.610418  19.503614
# 3      38.0  15.215685  4.545887   5.643341  12.475755  15.932311  18.613473
# 4      37.0  14.594901  4.239533   7.745933  11.774956  14.669927  16.979656
# 5       5.0  14.149549  6.773266   6.565988  10.657194  12.138869  17.219430
# 6       4.0  15.622920  4.215338  10.379905  13.165446  16.289124  18.746598
#
#             max
# size
# 1     32.573290
# 2     71.034483
# 3     23.074192
# 4     28.053517
# 5     24.166264
# 6     19.533528

# %% [markdown]
# The data in the first table above (total_bill)varies greatly for the various group sizes which would be expected as a party of 6 will obviously have a greater bill than a party of 1.
#
# Notably there's a tiny number of observations for party groups of 1/5/6 people. Given the low occurrences these figures probably aren't reliable.
#
# However the large observations for groups of 2 at 156 would indicate this might be more reliable. There's more reliable observations numbers for groups of 2/3/4 and from those 3 the best tippers by % are groups of 2.
#
# Interestingly the last table has less of a variation the mean 'TipPercent' for various group sizes. The majority are between 14.5% - 16.5% (roughly). The 21.7% for group size 1 is unreliable given there was only 4 solo diners in the dataset.

# %% [markdown]
# Summary for Categorical so far:
#
# **Key Findings**
#
# - Males have greater average bills, tip amounts & party size
# - **Womens tips are a greater percentage of their bill at 16.64% versus 15.76% for men**
# - DAY: For employers/staff Friday is clearly the least busy day with Saurday the busiest, dinner time is heading for three times busier than lunchtime.
# - Mean tip amount is highest on Sunday at 3.25 dollars followed in second place at 2.99 dollars on Saturdays (the weekend days)
# - **Mean tip by percentage is highest on Friday at 16.99%** followed on Sunday at 16.68%.
# - Little difference in total bill and tips left based on smoker status
# - **15.95% tip at dinner vs 16.41% at lunch**. So slightly better tips at lunch.
# - So dinner time is busier with lower tip %.
# - There's more reliable observations numbers for groups of 2/3/4 and from those 3 the **best tippers by % are groups of 2**.

# %% [markdown]
# **Multiple Variables**

# %% [markdown]
# A multi-variable analysis

# %% [markdown]
# The boxplot below takes the 'tip' variable and breaks it down into 'time' and also by 'sex'. It's clear that the IQR (inter-quartile range) is more widespread for men in comparison to women regardless of the time of day and the distribution as a whole is more widespread for men. It's also notable that means is lower for both men/women at luchtime as opposed to dinner time. However the mean tips are visibly similar for men and women throughout.

# %%
#Select style of grid
sns.set(style="darkgrid")
#alter plot size
fig = plt.figure(figsize=(12, 8))
# Display boxplot with time on x-axis and tip on y-axis
ax = sns.boxplot(x="time", y="tip", hue="sex", palette="Set1", data=tips).set_title("Distribution of tip broken by Time Categories & Sex")

# %% [markdown]
# A look at Day/Sex/Tip variables in boxplot below:
#
# - Pattern evident: More men pay bills than women and the distributions of 'tip' are more widespread for men on all 4 days when compared with women.
# - IQR's are visibly between 2-4 dollars on all days for both males/females.
# - Far more outlier visible on Saturdays in both male/female categories.
#
# As a waiter/waitress I'd assume a 50% or greater chance for getting a tip for between 2-4 dollars irrespective of day or sex. Also the outliers for 'tip' on Saturdays suggest it's a more likely day to get a generous tip from a customer (male or female).

# %%
#Select style of grid
sns.set(style="darkgrid")
#Alter figure/plot size
fig = plt.figure(figsize=(12, 6))
# Display boxplot with time on x-axis and tip on y-axis
ax = sns.boxplot(x="day", y="tip", hue="sex", palette="Set1", data=tips).set_title("Distribution of tip broken into Day/Sex Categories")

# %% [markdown]
# The violin plot below is an alternative version for illustration purposes:

# %%
# Take tip on the different days and look to see if there's a visible difference when data is broken into male/female categories
# Adapted code from [4]
sns.catplot(x="day", y="tip", hue="sex", kind="violin", palette="Set1", data=tips)
#Display plot
plt.show()

# %% [markdown]
# **_Pair Plots for Numerical Data_**
#
# Pairplots can be used to show the relationships between variables within a dataset. This series of scatterplots gives a good summary of the relationship between numerical variables. Along the diagonal from top left to bottom right we can see the distribution of each single variable.
#
# Each variable is plotted against itself aswell as all other numerical variables here and so it possible to see both distribution of single variables and the relationships between two variables.

# %% [markdown]
# _Pair Plots using Seaborn_
#
# - Plot image below has 5 columns and 5 rows
# - Visible on the left/bottom of the image is the numerical variables ie. TipPercent/BillandTip/size/tip/total_bill
# - On the right you can see male data is orange whilst female data is blue
# - across the diagonal (top left to bottom right) is a kernel density function - basic plot of one variable
# - for example: the top left plot has _total bill_ on the _y-axis_ and _total bill_ on the _x-axis_ and the bottom left plot has  _TipPercent_ on the _y-axis_ and _total bill_ on the _x-axis_

# %%
#pass pair plot in dataframe to investigate numerical variables relationships
sns.pairplot(df, palette="Set1")

# %%
#Add in a regression line to clearly see if there's a linear relationship.
sns.pairplot(df, kind="reg", palette="Set1")

# %% [markdown]
# **Similarly in the pairplot differeniated by gender below the same patterns emerge so little overall change when data is analysed by gender.**

# %% [markdown]
# Here I'm focusing on the original 3 columns in the dataset (tip/total_bill/size) so the nine plots in top left of pairplot.
#
# - In the pairplots above there **a strong positive relationship evident between tip and total_bill**. Dots increase from left to right in plot in a relatively straight pattern. So as bill increases tip also increases and vice-versa.
# - When a regression line is added as in plots below it's further evident there's a strong positive relationship between tip and total_bill which is linear.
# - **There a positive linear relationship between size and tip and between total_bill and size but it's not as strong.** The regression line slope is not as steep.

# %%
#pass pair plot in dataframe (df) displaying data by sex (male in orange, female is blue)
sns.pairplot(df, hue='sex', palette="Set1")

# %% [markdown]
# ## 4. Relationship between Tip and Total Bill & Regression

# %% [markdown]
# Now we'll go back to look at two numberical variables 'tip' and 'total_bill'. Is there a relationship between them? Is there a linear pattern evident?

# %% [markdown]
# **Linear Regression Models**
#
# "Two main functions in seaborn are used to visualize a linear relationship as determined through regression. These functions, **regplot()** and **lmplot()** are closely related, and share much of their core functionality..., both functions draw a scatterplot of two variables, x and y, and then fit the regression model y ~ x and plot the resulting regression line and a 95% confidence interval for that regression."[11]
#
# A regression line put simply a single line that best fits the given data.
#
# "In statistical modeling, regression analysis is a set of statistical processes for estimating the relationships between a dependent variable (often called the 'outcome variable') and one or more independent variables (often called 'predictors', 'covariates', or 'features'). The most common form of regression analysis is linear regression, in which a researcher finds the line (or a more complex linear function) that most closely fits the data according to a specific mathematical criterion" [12].

# %% [markdown]
# **What is Seaborn's lmplot?**
#
#
# - a 2D scatterplot
# - with an optional overlaid regression line
# - you can set the horizontal and vertical labels by selecting the x and y values (total_bill and tip)

# %% [markdown]
# **lmplot() vs regplot()**
#
# - the _lmplot()_ accepts variables in a variety of formats like numpy arrays, pandas series objects, or as variables in a pandas DataFrame
#
# - the _regplot()_ has data as a required parameter and the x and y variables must be specified as strings.

# %%
#Generate regplot
sns.regplot(x="total_bill", y="tip", data=tips, line_kws={'color': 'red'})
plt.show()

# %%
# code adapted from stackoverflow [10] to change line colour
#Generate lmplot
sns.lmplot(x="total_bill", y="tip", data=tips, line_kws={'color': 'red'} )
plt.show()

# %% [markdown]
# **These plots depict the strong positive linear correlation between the two variables 'tip' and 'total_bill'.** The regression line in red is straight and it gives the best average for the all the data points.
#
# **Also as similarly stated earlier the bill amount from the plots above seems to be mostly between 10-25 dollars with tips mostly between about 1.5-3.8 dollars (roughly).**

# %% [markdown]
# **BY GENDER**

# %%
#Generate lmplot for variables 'tip and total_bill' by gender
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex" )
plt.show()

# %% [markdown]
# When a similar plot is generated and data is highlighted** by gender again it's clear there's a positive linear relationship between tip and total_bill**. The two regression lines are very similar and are so close it's almost hard to distinguish them in this plot.

# %% [markdown]
# **By DAY**

# %%
#Generate lmplot for variables 'tip and total_bill' by gender
sns.lmplot(x="total_bill", y="tip", data=tips, hue="day" )
plt.show()

# %% [markdown]
# **By day this plt again show positive correlation between tip and total_bill for each day but with varying degrees of strength in that Saturday appears to have the steepest slope ie. more positive linear relationship than Sunday for instance.**

# %%
df.describe() # now look at Summary Statistics with new Columns
# Out:
#        total_bill         tip        size  BillandTip  TipPercent
# count  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672   22.784221   16.080258
# std      8.902412    1.383638    0.951100    9.890116    6.107220
# min      3.070000    1.000000    1.000000    4.070000    3.563814
# 25%     13.347500    2.000000    2.000000   15.475000   12.912736
# 50%     17.795000    2.900000    2.000000   20.600000   15.476977
# 75%     24.127500    3.562500    3.000000   27.722500   19.147549
# max     50.810000   10.000000    6.000000   60.810000   71.034483

# %% [markdown]
# Going back to the descriptive statistics to remember the mean values for tip was 2.99 dollars (16.08%) and the mean total_bill was 19.78 dollars.
#
# Given from earlier findings that the largest group size was 2 (64%) and from the table below we can see that of group of size 2 were men paid they left a 16.26% tip or 2.61 dollars.
#
# So I think it's fair to conclude that a tip of around 16% can be estimated by employers and staff in the restaurant based on these findings.

# %%
#generate table to illustrate mean numerical data for group size broken down by gender
df.groupby(['size', 'sex']).mean()
# Out:
#              total_bill       tip  BillandTip  TipPercent
# size sex
# 1    Female    6.796667  1.276667    8.073333   21.513061
#      Male      8.580000  1.920000   10.500000   22.377622
# 2    Female   15.339483  2.528448   17.867931   17.082992
#      Male     17.104082  2.614184   19.718265   16.269448
# 3    Female   21.547143  3.250000   24.797143   15.989858
#      Male     24.287083  3.476667   27.763750   14.764085
# 4    Female   30.278889  4.021111   34.300000   13.273446
#      Male     28.078214  4.172143   32.250357   15.019654
# 5    Female   29.850000  5.140000   34.990000   17.219430
#      Male     30.122500  3.750000   33.872500   13.382079
# 6    Female   28.425000  4.600000   33.025000   16.289124
#      Male     41.235000  5.850000   47.085000   14.956716

# %% [markdown]
# ## 5. Conclusion

# %% [markdown]
# # 6. References
#
# [1] https://en.wikipedia.org/wiki/Gratuity accessed 19/Nov/19
#
# [2] https://en.wikipedia.org/wiki/Tipped_wage 19/Nov/19
#
# [3] https://www.economist.com/the-economist-explains/2018/06/21/why-tipping-in-america-is-up-for-debate accessed 19/Nov/19
#
# [4] https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset accessed 19/Nov/19
#
# [5] https://www.kaggle.com/ranjeetjain3/seaborn-tips-dataset/version/1# accessed 13/Nov/19
#
# [6] https://towardsdatascience.com/a-quick-guide-on-descriptive-statistics-using-pandas-and-seaborn-2aadc7395f32 accessed 18/Nov/19
#
# [7] https://seaborn.pydata.org/generated/seaborn.boxplot.html accessed 18/Nov/19
#
# [8] https://towardsdatascience.com/analyze-the-data-through-data-visualization-using-seaborn-255e1cd3948e accessed 18/Nov/19
#
# [9] https://towardsdatascience.com/understanding-boxplots-5e2df7bcbd51
#
# [10] https://stackoverflow.com/questions/35827268/how-to-change-the-line-color-in-seaborn-lmplot accessed 27/Nov/19
#
# [11] https://seaborn.pydata.org/tutorial/regression.html accessed 28/Nov/19
#
# [12] https://en.wikipedia.org/wiki/Regression_analysis
#
#
# # Bibliography
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://towardsdatascience.com/a-quick-guide-on-descriptive-statistics-using-pandas-and-seaborn-2aadc7395f32
#
# https://dfrieds.com/data-analysis/groupby-python-pandas
#
# https://pythonbasics.org/seaborn_line_plot/
